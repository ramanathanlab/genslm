# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

# %%
df = df.append({'num_nodes': 1, "num_params": "2.5B", "average_throughput": 6.498, "sample_time_avg": 0.1539}, ignore_index = True)

# %%
df = df.sort_values(by=['num_nodes'])

# %%
df
# Out:
#     average_throughput  num_nodes num_params  sample_time_avg
# 0               42.570        1.0       250M         0.023490
# 17               6.498        1.0       2.5B         0.153900
# 1               80.081        1.0        25M         0.012490
# 2               80.546        2.0       250M         0.012420
# 3              156.657        2.0        25M         0.006383
# 4               13.482        2.0       2.5B         0.074170
# 5              307.445        4.0        25M         0.003253
# 6               27.133        4.0       2.5B         0.036860
# 7              158.595        4.0       250M         0.006305
# 9              576.249        8.0        25M         0.001735
# 8              305.066        8.0       250M         0.003278
# 10             210.943       32.0       2.5B         0.004741
# 11             727.133      128.0       2.5B         0.001375
# 12            3226.762      128.0        25M         0.000310
# ...

# %%
list(df[df['num_params'] == "2.5B"]['average_throughput'])
# Out:
# [6.498, 13.482, 27.133, 210.943, 727.133, 1075.22]
