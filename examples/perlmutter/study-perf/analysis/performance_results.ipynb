# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.DataFrame()

# %%
df = df.append({'num_nodes': 8, "num_params": "2.5B", "average_throughput": 54.161, "sample_time_avg": 0.01846}, ignore_index = True)

# %%
df = df.sort_values(by=['num_nodes', 'num_params'])

# %%
df
# Out:
#     average_throughput  num_nodes num_params  sample_time_avg
# 0                6.498        1.0       2.5B         0.153900
# 1               42.570        1.0       250M         0.023490
# 2               80.081        1.0        25M         0.012490
# 3               13.482        2.0       2.5B         0.074170
# 4               80.546        2.0       250M         0.012420
# 5              156.657        2.0        25M         0.006383
# 6               27.133        4.0       2.5B         0.036860
# 7              158.595        4.0       250M         0.006305
# 8              307.445        4.0        25M         0.003253
# 25              54.161        8.0       2.5B         0.018460
# 9              305.066        8.0       250M         0.003278
# 10             576.249        8.0        25M         0.001735
# 11             565.139       16.0       250M         0.001769
# 12            1027.873       16.0        25M         0.000973
# ...

# %%
list(df[df['num_params'] == "2.5B"]['average_throughput'])
# Out:
# [6.498, 13.482, 27.133, 54.161, 210.943, 396.31, 727.133, 1075.22]

# %%
df.to_csv("initial_results.csv")
