# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.DataFrame()

# %%
df = df.append({'num_nodes': 64, "num_params": "2.5B", "average_throughput": 396.31, "sample_time_avg": 0.002524}, ignore_index = True)

# %%
df = df.sort_values(by=['num_nodes', 'num_params'])

# %%
df
# Out:
#     average_throughput  num_nodes num_params  sample_time_avg
# 1                6.498        1.0       2.5B         0.153900
# 0               42.570        1.0       250M         0.023490
# 2               80.081        1.0        25M         0.012490
# 5               13.482        2.0       2.5B         0.074170
# 3               80.546        2.0       250M         0.012420
# 4              156.657        2.0        25M         0.006383
# 7               27.133        4.0       2.5B         0.036860
# 8              158.595        4.0       250M         0.006305
# 6              307.445        4.0        25M         0.003253
# 10             305.066        8.0       250M         0.003278
# 9              576.249        8.0        25M         0.001735
# 12             565.139       16.0       250M         0.001769
# 11            1027.873       16.0        25M         0.000973
# 13             210.943       32.0       2.5B         0.004741
# ...

# %%
list(df[df['num_params'] == "250M"]['average_throughput'])
# Out:
# [42.57, 80.546, 158.595, 305.066, 565.139, 962.113, 1493.05, 2050.49, 2416.772]

# %%
df.to_csv("initial_results.csv")
